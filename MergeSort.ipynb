# %%
import numpy as np
import operator


def mergeSort(array, left_index, right_index):
    if left_index >= right_index:
        return

    middle = (left_index + right_index)//2
    mergeSort(array, left_index, middle)
    mergeSort(array, middle + 1, right_index)
    merge(array, left_index, right_index)

def merge(left, right):
    merge_result = []

    left_index = right_index = 0
    while left_index < len(left) and right_index < len(right):
        if left[left_index] > right[right_index]:
            merge_result.append(right[right_index])
            right_index += 1
        else:
            merge_result.append(left[left_index])
            left_index += 1

    merge_result += left[left_index:]
    merge_result += right[right_index:]

    return merge_result

array1000=np.random.randint(0,100,1000)
array2000=np.random.randint(0,100,2000)
array5000=np.random.randint(0,100,5000)
array10000=np.random.randint(0,100,10000)
array20000=np.random.randint(0,100,20000)
array30000=np.random.randint(0,100,30000)
print(array1000)
mergeSort(array1000)
print(array1000)
mergeSort(array2000)
print(array2000)
mergeSort(array5000)
print(array5000)
mergeSort(array10000)
print(array10000)
mergeSort(array50000)
print(array50000)
mergeSort(array1000,0,len(array1000) -1)
print(array1000)
# Out:
# [42 55 76 13 71 85 42 35 81 63 71 47 56 41  0 64 87 71 36 67 99 37 87 59
#  27 25 42 64 84 55 74 86 77 54 53 50 57 48 21  3  8 83 26 65 12 42 56 68
#  93 68  2 43 85 42 35 24 30 64 96 49 92 57 75 37 91 76 96 82 33 56 90 49
#  89 82 70 26  5 79 49 70 52 99 66 40 29 70 37 54 11 81 86 14 26 33 96 77
#  12  2 73 14 40 88  2 89 35 13 89 82 27  1 29 85  1 85 98 54  5 47 10 53
#  21 47 97 26 43 31  3 72 59 50 31 92 18 90 96 55 11 96 83 52 41  2  3 31
#  63 63 37 70 71  0 68  2 57  8 73 88 61 32 68 77 21  0  5  2 50 14 94  7
#   8 86 23 12 67 76 62 16 47 81 97 73 65 35 97 74 61 31 50 25 14 90 39 18
#  63 24 78 47 50 93 79 61 96 55 90 52 73 17 83 64 71  0 73 68  3 89 48  0
#   9  3 51 59 59 49 13 75  5 89 54 11 80 32 62 27 57 74 26 61 73 47 50 62
#  79 16 62 99 54 58 65 25 97 50 91 16 55 68 43 73 87 46 28  4 50 69 59 40
#  89  3 99 64 78 44 66 25 87 18 43 47 97 19 81 70 60  2 88 56 83 31 26 72
#  82 39  7 43  4 21 30 71 24 94 67 29 17 95  1 82 36 84 68 94 36 84 61 20
# ...
